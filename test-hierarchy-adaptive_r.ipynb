# %%
from __future__ import print_function, division
import sys, os, time
import itertools
import copy
import warnings
import time
import math
# scientific computing libraries
import torch
import numpy as np
import cvxpy as cp
from cvxpylayers.torch import CvxpyLayer

from scipy.sparse import coo_matrix, csc_matrix
import matplotlib.pyplot as plt
from scipy.interpolate import BPoly
from mpl_toolkits.mplot3d.art3d import Poly3DCollection
import matplotlib.pyplot as plt

# third party libraries
import mosek
from tabulate import tabulate

from libott import loadTGP, construct_P, construct_A, gradient_from_P, gradient_from_A, set_print_level
from libbezier import Bezier

DO_PLOT_RESULTS = True


def print_green(*args, **kwargs):
    print("\033[1;32m", end='')
    print(*args, **kwargs)
    print("\033[0m", end='')

def print_yellow(*args, **kwargs):
    print("\033[1;33m", end='')
    print(*args, **kwargs)
    print("\033[0m", end ='')

def print_purple(*args, **kwargs):
    print("\033[1;34m", end='')
    print(*args, **kwargs)
    print("\033[0m", end='')

def print_red(*args, **kwargs):
    print("\033[1;35m", end='')
    print(*args, **kwargs)
    print("\033[0m", end='')

def print_cyan(*args, **kwargs):
    print("\033[1;36m", end='')
    print(*args, **kwargs)
    print("\033[0m", end='')

def print_gray(*args, **kwargs):
    print("\033[1;37m", end='')
    print(*args, **kwargs)
    print("\033[0m", end='')


class IndoorOptProblem(object):
    """Convex optimization around corridor approach for drone trajectory optimization.

    Currently it support problem where each corridor has been specified a time, later we will let it be free.
    """
    def __init__(self, tgp, tfweight=0, connect_order=2, verbose=False):
        """Constructor for this problem class.

        Parameters
        ----------
        tgp: a PyTGProblem object.
        tfweight: float, the weight on transfer time
        connect_order: to which order of derivative at connection do we guarantee continuity.
        verbose: bool, if the solver is verbose
        """
        self.floor = tgp  # I shall still use the floor name for convenience
        self.x0_pack = [tgp.position[0], tgp.velocity[0], tgp.acceleration[0]]
        self.xf_pack = [tgp.position[1], tgp.velocity[1], tgp.acceleration[1]]
        self.tfweight = tfweight
        self.obj_order = tgp.minimizeOrder
        self.poly_order = tgp.trajectoryOrder
        self.connect_order = connect_order  # guarantee acceleration continuity
        self.verbose = verbose
        self.margin = tgp.margin
        self.is_limit_vel = tgp.doLimitVelocity
        self.is_limit_acc = tgp.doLimitAcceleration
        self.vel_limit = tgp.maxVelocity  # component wise limit on velocity
        self.acc_limit = tgp.maxAcceleration  # component wise limit on acceleration
        # get info on environment
        self.boxes = tgp.getCorridor()
        self.num_box = len(self.boxes)
        self.room_time = np.array([box.t for box in self.boxes])
        bz = Bezier(self.poly_order, self.poly_order, self.obj_order)
        self.bz = bz
        self.bzM = self.bz.M()[self.poly_order]  # use this for some output stuff
        self.MQM = self.bz.MQM()[self.poly_order]
        self.h_type = "l"
        if verbose:
            print('has %d boxes' % self.num_box)
            print('init time ', self.room_time)
        # some default settings such as how close you can reach the corner
        self.abs_obj_tol = 1e-3  # this controls absolute objective tolerance and should not set small for problem with small obj
        self.rel_obj_tol = 1e-5  # this controls relative objective tolerance
        self.grad_tol = 1e-3  # this controls gradient tolerance
        self.r = 0.4  # 0.00006 can converge


    def set_tfweight(self, weight):
        """Set weight on time"""
        self.tfweight = weight

    def construct_prob(self, x0_pack, xf_pack, poly_order, obj_order, connect_order):
        """Construct a problem."""
        pass

    def set_x0_pack_value(self, *args):
        """Set the contents of x0pack"""
        ff = zip(self.x0_pack, args)
        print(ff)
        for tmp, val in zip(self.x0_pack, args):
            tmp[:] = val[:]

    def set_xf_pack_value(self, *args):
        """Set the contents of xfpack"""
        for tmp, val in zip(self.xf_pack, args):
            tmp[:] = val[:]

    def solve_with_room_time(self, rm_time):
        """Specify room time and solve the problem"""
        raise NotImplementedError("Subclass should implement solve_with_room_time function")

    def get_output_coefficients(self, ):
        """
        Get the monomial coefficients representing a piece-wise polynomial trajectory
        return ndarray, (s, 1), time allocated for each segment 
        return ndarray, (s, o + 1, d), polynomial coefficients, where s is the number of segments, 
        o is the order of trajectory, d is the number of dimensions, which is 3
        """
        
        n_room = self.num_box
        
        poly_coef = np.zeros([n_room, self.poly_order + 1, 3])
        
        # coefficients in bezier and scaled form
        mat_x = np.reshape(self.sol, (n_room, 3, self.poly_order + 1))
        mat_x = np.transpose(mat_x, (0, 2, 1))

        # change coefficients to monomial and unscaled form
        for i in range(n_room):
            poly_coef[i, :, :] = self.bzM.dot(mat_x[i]) * self.room_time[i]

        return self.room_time.copy(), poly_coef

    def get_coef_matrix(self):
        """Return coefficients"""
        # self.sol = np.zeros((self.num_box*3*(self.poly_order + 1)))
        coef_mat = np.reshape(self.sol, (self.num_box, 3, self.poly_order + 1))
        coef_mat = np.transpose(coef_mat, (0, 2, 1))
        #import pdb; pdb.set_trace()
        for i in range(self.num_box):
            coef_mat[i] *= self.room_time[i]
        return coef_mat

    def get_coef_matrix2(self):
        """
        Return Bezier coefficients
        """
        # self.sol = np.zeros((self.num_box*3*(self.poly_order + 1)))
        coef_mat = np.reshape(self.sol, (self.poly_order + 1, 3, self.num_box), order='F')
        coef_mat = coef_mat.transpose((0,2,1))
        #import pdb;pdb.set_trace()
        for i in range(self.num_box):
            coef_mat[:,i,:] *= self.room_time[i]
        
        return coef_mat


    def from_coef_matrix(self, mat_in):
        """Assign values to sol based on the input coefficient matrix."""
        self.sol = np.zeros(mat_in.size)
        coef_mat = np.reshape(self.sol, (self.num_box, 3, self.poly_order + 1))
        for i in range(self.num_box):
            coef_mat[i] = mat_in[i].T / self.room_time[i]
        with np.printoptions(precision=4, linewidth=10000):
            print(self.sol)

    def get_output_path(self, n):
        """Get a path for output that is linspace in time.

        :param n: int, the number of nodes for a path
        :return: float, the total time for this problem
        :return: ndarray, (n, 2) the optimal path
        """
        cum_sum_time = np.cumsum(self.room_time)
        output = np.zeros((n, 3))  # the output trajectory
        sample_time = np.linspace(0, cum_sum_time[-1], n)
        n_room = self.num_box

        # get all the coef of polynomials
        t, all_poly_coeffs = self.get_output_coefficients()
        for i in range(n_room):
            # poly_coef = self.bzM.dot(mat_x[i]) * self.room_time[i]
            poly_coef = all_poly_coeffs[i,:,:]
            if i == 0:
                t_mask = sample_time <= cum_sum_time[0]
                use_s = sample_time[t_mask] / cum_sum_time[0]
            else:
                t_mask = (sample_time > cum_sum_time[i - 1]) & (sample_time <= cum_sum_time[i])
                use_s = (sample_time[t_mask] - cum_sum_time[i - 1]) / self.room_time[i]
            output[t_mask, 0] = np.polyval(poly_coef[:, 0][::-1], use_s)
            output[t_mask, 1] = np.polyval(poly_coef[:, 1][::-1], use_s)
            output[t_mask, 2] = np.polyval(poly_coef[:, 2][::-1], use_s)
        return cum_sum_time[-1], output

    def get_gradient(self):
        raise NotImplementedError

    def get_gradient_fd(self, h=1e-6):
        """Use forward finite difference to approximate gradients."""
        grad = np.zeros(self.num_box)
        obj0 = self.obj
        origin_time = self.room_time.copy()
        for i in range(self.num_box):
            try_time = origin_time.copy()
            try_time[i] += h
            self.solve_with_room_time(try_time)
            grad[i] = (self.obj - obj0) / h
        grad += self.tfweight
        return grad

    def get_gradient_mellinger(self, h=1e-6):
        """
        Use finite difference described in:
        http://www-personal.acfr.usyd.edu.au/spns/cdm/papers/Mellinger.pdf
        to approximate gradients.
        """
        grad = np.zeros(self.num_box)
        obj0 = self.obj
        origin_time = self.room_time.copy()
        for i in range(self.num_box):
            m = self.num_box
            gi = -1/(m-1) * np.ones(m)
            gi[i] = 1
            try_time = origin_time.copy()
            try_time += h * gi
            # print("In gg Mellinger: gi", gi," try_time: ", try_time)
            self.solve_with_room_time(try_time)
            grad[i] = (self.obj - obj0) / h
        grad += self.tfweight
        return grad

    def draw3D(self):
        # plot 3D trajectory
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        boxes = tgp.getCorridor()

        poly_coef = solver.get_coef_matrix().transpose((1,0,2))
        break_points = np.insert(np.cumsum(solver.room_time), 0, 0.0)
        initial_trajectory = BPoly(poly_coef, break_points)
        tt_initial = np.linspace(0.0, break_points[-1], 100)

        # poly_coef = solver.get_coef_matrix2()
        # final_trajectory = BPoly(poly_coef, break_points)
        # tt_final = np.linspace(0.0, break_points[-1], 100)

        from mpl_toolkits.mplot3d.art3d import Poly3DCollection



        def set_axes_equal(ax):
            '''Make axes of 3D plot have equal scale so that spheres appear as spheres,
            cubes as cubes, etc..  This is one possible solution to Matplotlib's
            ax.set_aspect('equal') and ax.axis('equal') not working for 3D.

            Input
            ax: a matplotlib axis, e.g., as output from plt.gca().
            '''

            x_limits = ax.get_xlim3d()
            y_limits = ax.get_ylim3d()
            z_limits = ax.get_zlim3d()

            x_range = abs(x_limits[1] - x_limits[0])
            x_middle = np.mean(x_limits)
            y_range = abs(y_limits[1] - y_limits[0])
            y_middle = np.mean(y_limits)
            z_range = abs(z_limits[1] - z_limits[0])
            z_middle = np.mean(z_limits)

            # The plot bounding box is a sphere in the sense of the infinity
            # norm, hence I call half the max range the plot radius.
            plot_radius = 0.5*max([x_range, y_range, z_range])

            ax.set_xlim3d([x_middle - plot_radius, x_middle + plot_radius])
            ax.set_ylim3d([y_middle - plot_radius, y_middle + plot_radius])
            ax.set_zlim3d([z_middle - plot_radius, z_middle + plot_radius])

        for i in range(len(boxes)):
            vertices = boxes[i].vertex
            ax.scatter(vertices[:, 0], vertices[:, 1], vertices[:, 2], s=1)
            Z = vertices            
            verts = [[Z[0],Z[1],Z[2],Z[3]],
                        [Z[4],Z[5],Z[6],Z[7]], 
                        [Z[0],Z[1],Z[5],Z[4]], 
                        [Z[2],Z[3],Z[7],Z[6]], 
                        [Z[1],Z[2],Z[6],Z[5]],
                        [Z[4],Z[7],Z[3],Z[0]], 
                        [Z[2],Z[3],Z[7],Z[6]]]

            # plot safe corridor
            pc = Poly3DCollection(verts, alpha = 0.0, facecolor='gray', linewidths=0.1, edgecolors='red')
            ax.add_collection3d(pc)

        ax.plot(initial_trajectory(tt_initial)[:,0], initial_trajectory(tt_initial)[:,1], initial_trajectory(tt_initial)[:,2], label="Before refinement")
        # ax.plot(final_trajectory(tt_final)[:,0], final_trajectory(tt_final)[:,1], final_trajectory(tt_final)[:,2], label="After refinement")

        ax.scatter(tgp.position[0,0], tgp.position[0,1], tgp.position[0,2], marker="*", s=20, label="Start")
        ax.scatter(tgp.position[1,0], tgp.position[1,1], tgp.position[1,2], marker="o", s=20, label="Goal")
        set_axes_equal(ax)
        ax.set_axis_off()
        ax.legend()
        ax.set_title("3D trajectory")

        """Formulate the indoor navigation problem explicitly as QP so we can either use mosek or osqp to solve it.

    I will manually maintain those matrices and hope it is more efficient.
    """


    def update_prob(self):
        """Just update the problem since we are changing pretty fast.

        This function assume you might have change in room sequence so it reconstructs things. Take care with this.
        """
        self.construct_prob(self.x0_pack, self.xf_pack, self.poly_order, self.obj_order, self.connect_order)

    def construct_prob(self, x0_pack, xf_pack, poly_order, obj_order, connect_order):
        """Construct a problem."""
        # construct the problem using Fei's code
        # self.construct_P()
        self.construct_A()

    def construct_P(self):
        # P is fixed and we do not alter it afterwards, so let's keep going

        pval, prow, pcol = construct_P(self.obj_order, self.num_box, self.poly_order, self.room_time, self.MQM, self.h_type)
        self.sp_P = coo_matrix((pval, (prow, pcol)))  # ugly hack since osqp only support upper triangular part or full
        self.n_var = self.sp_P.shape[0]
        # self.qp_P = spmatrix(sp_P.data, sp_P.row, sp_P.col)
        self.qp_q = np.zeros(self.n_var)

    def construct_A(self):
        lincon = construct_A(
                self.floor.getCorridor(),
                self.MQM,
                self.floor.position.copy(order='F'),
                self.floor.velocity.copy(order='F'),
                self.floor.acceleration.copy(order='F'),
                self.floor.maxVelocity,
                self.floor.maxAcceleration,
                self.floor.trajectoryOrder,
                self.floor.minimizeOrder,
                self.floor.margin,
                self.floor.doLimitVelocity,
                self.floor.doLimitAcceleration)
        self.xlb = lincon.xlb
        self.xub = lincon.xub
        self.clb = lincon.clb
        self.cub = lincon.cub
        # we need more
        self.sp_A = coo_matrix((lincon.aval, (lincon.arow, lincon.acol)))
        self.n_con = self.sp_A.shape[0]
        if self.verbose > 1:
            print('n_con', self.n_con)
            print('n_var', self.sp_A.shape[1])
            print("A has %d nnz" % lincon.aval.shape[0])

    def eval_cost_constr(self, mat_in):
        """Pass in a coefficient matrix, see results."""
        self.from_coef_matrix(mat_in)  # update self.sol
        self.update_prob()
        cost = 0.5 * self.sol.dot(self.sp_P.dot(self.sol))
        Ax = self.sp_A.dot(self.sol)
        # equality part
        error_clb = np.minimum(Ax - self.clb, 0)
        error_cub = np.minimum(-Ax + self.cub, 0)
        error_lb = np.minimum(self.sol - self.xlb, 0)
        error_ub = np.minimum(self.xub - self.sol, 0)
        with np.printoptions(precision=4, linewidth=10000):
            print('cost %f' % cost)
            print('error_eq', np.minimum(error_clb, error_cub))
            print('error_ieq', np.minimum(error_lb, error_ub))

    def get_gradient(self, sol, lmdy, lmdz):
        pgrad = gradient_from_P(self.obj_order, self.num_box, self.poly_order, self.room_time, self.MQM, sol)
        agrad = gradient_from_A(
                    self.floor.getCorridor(),
                    self.MQM,
                    self.floor.position.copy(order='F'),
                    self.floor.velocity.copy(order='F'),
                    self.floor.acceleration.copy(order='F'),
                    self.floor.maxVelocity,
                    self.floor.maxAcceleration,
                    self.floor.trajectoryOrder,
                    self.floor.minimizeOrder,
                    self.floor.margin,
                    self.floor.doLimitVelocity,
                    self.floor.doLimitAcceleration,
                    sol,
                    lmdy,
                    lmdz)
        if self.verbose > 1:
            print('pgrad', pgrad)
            print('agrad', agrad)
        return pgrad + agrad + self.tfweight

    def solve_once(self):
        """Solve the original problem once."""
        raise NotImplementedError
    

    def solve_with_room_time(self, rm_time): ###new candidate time y
        self.room_time[:] = rm_time
        self.floor.updateCorridorTime(self.room_time)
        return self.solve_once()
    
        

    def Monopoly(self, alpha0=0.002, h=1e-5, c=0.2, tau=0.2, max_iter=5000, j_iter=5, log=False, timeProfile=False, adaptiveLineSearch=False):
        """Use backtrack line search to refine time. We fix total time to make things easier.

        Parameters
        ----------
        alpha0: float, initial step length 0.175 and 0.375 are found to be very good.
        h: float, step size for finding gradient using forward differentiation
        c: float, the objective decrease parameter
        tau: float, the step length shrink parameter
        max_iter: int, maximum iteration for gradient descent
        j_iter: int, maximum iteration for finding alpha
        abs_tol: float, absolute objective tolerance
        rel_tol: float, Relative objective tolerance
        Returns
        -------
        is_okay: bool, indicates if some exception occurs
        converged: bool, indicates if the algorithm converges
        """

        if log == True:
            self.log = np.array([])
            self.log = np.append(self.log, [self.obj, 0])

        if timeProfile == True:
            self.timeProfile = np.array([])

        t0 = time.time()
        self.major_iteration = 0
        self.num_prob_solve = 0
        if self.num_box == 1 and self.tfweight == 0:
            self.major_iteration = 0
            self.num_prob_solve = 0
            self.time_cost = time.time() - t0
            self.converge_reason = 'No need to refine'
            return True, True
        n_room = self.num_box
        # t_now = self.room_time.copy()
        y = torch.from_numpy(self.room_time)
        y.requires_grad_()

        converged = False
        converge_reason = 'Not converged'
        num_prob_solve = 0  # record number of problems being solved for a BTLS
        T = 3
        dim = 3*self.num_box*(self.poly_order+1)
        # c_0 = torch.zeros(dim, dtype=torch.double,requires_grad=True)
        c_0 = torch.tensor([dim*[0]], dtype=torch.double,requires_grad=True)


        obj = torch.zeros(1, dtype=torch.double,requires_grad=True)
        for i in range(max_iter):
            y.requires_grad_()
            if self.verbose:
                print_green('Iteration %d' % i)
           
            obj0 = obj
            is_okay = True
            
            if timeProfile == True:
                tBeforeGrad = time.time()

            self.floor.updateCorridorTime(y.detach().numpy())
            IndoorOptProblem.update_prob(self) #update y for c
            c = c_0
            qval, qrow, qcol = Hierarchy_free.construct_P_matrix(self.obj_order, self.num_box, self.poly_order, y, self.MQM, self.h_type)
            # p_y = torch.sparse_coo_tensor((qrow, qcol), qval).to_sparse_csr()
            p_y = torch.sparse_coo_tensor((qrow, qcol), qval).to_dense()
            p_y = p_y + p_y.t() - torch.diag(p_y.diagonal())
            #y = torch.from_numpy(self.room_time)
            #y.requires_grad_()
            
            i = 0
            while i < T:
                c = Hierarchy_free.h(self, p_y, y, c)
                i += 1
    
            # print(np.shape(Hierarchy_free.solve_Jacobian(y,c))) 
             
            obj = Hierarchy_free.l(self, p_y, y, c)
            print(obj)
            obj.backward()  
            grad = y.grad.detach().numpy()

            candidit_y= y.detach().numpy()
            # choose a method to calculate gradient
            # if self.grad_method == 'ours':
            #     grad = y.grad
            # elif self.grad_method == 'fd':
            #     grad = self.get_gradient_fd(h=0.25*1e-6)
            # elif self.grad_method == 'mel':
            #     grad = self.get_gradient_mellinger(h=0.25*1e-6)
            # else:
            #     print_red("No this grad method!")
            
            if timeProfile == True:
                tAfterGrad = time.time()
                self.timeProfile = np.append(self.timeProfile, [tAfterGrad - tBeforeGrad])

            #print_red('grad_an ', grad, ' grad_fd ', grad_fd, 'grad_mel', grad_mel)
            if self.tfweight == 0:
                # get projected gradient, the linear manifold is \sum x_i = 0; if tfweight=0, we fix total time
                normal = np.ones(n_room) / np.sqrt(n_room) # normal direction
                grad = grad - grad.dot(normal) * normal  # projected gradient descent direction
            # print_red('grad_an ', grad / np.linalg.norm(grad), ' grad_fd ', grad_fd / np.linalg.norm(grad_fd), 'grad_mel', grad_mel / np.linalg.norm(grad_mel))
            # print_yellow('sum_an ', np.sum(grad), 'sum_fd ', np.sum(grad_fd), 'sum_mel ', np.sum(grad_mel))
            if np.linalg.norm(grad) < self.grad_tol:  # break out if gradient is too small
                if self.verbose:
                    print('Gradient too small')
                converged = True
                converge_reason = 'Small gradient'
                break
            if self.verbose:
                print_green('At time ', candidit_y, ' grad is ', grad)
            m = -np.linalg.norm(grad)
            p = grad / m  # p is the descending direction
            # use a maximum alpha that makes sure time are always positive
            alpha_max = np.amax(-candidit_y / p) - 1e-6  # so I still get non-zero things
            if alpha_max > 0:
                alpha = min(alpha_max, alpha0)
            else:
                alpha = alpha0
            # t = -c * m

            # find alpha
            alpha_found = False

            if timeProfile == True:
                tBeforeAlpha = time.time()

            for j in range(j_iter):
                if self.verbose:
                    print('Search alpha step %d, alpha = %f' % (j, alpha))
                candidit_y = candidit_y + alpha * p

                # lower bound on the alpha
                if adaptiveLineSearch == True:
                    if alpha < 1e-4:
                        if self.verbose:
                            print_yellow('Stop line search because alpha is too small')
                        break
                
                # make sure that time will not go too small
                if np.any(candidit_y < 1e-6):
                    alpha = tau * alpha
                    continue
                alpha_found = True
                break
                

            if timeProfile == True:
                tAfterAlpha = time.time()
                self.timeProfile = np.append(self.timeProfile, [tAfterAlpha - tBeforeAlpha])

            if self.verbose:
                if alpha_found:
                    print('We found alpha = %f' % alpha)
                else:
                    print('Fail to find alpha, use a conservative %f' % alpha)
            if not alpha_found:  # for case where alpha is not found
                converge_reason = 'Cannot find step size alpha'
                is_okay = True
                converged = False
                # roll back to t_now
                self.room_time = candidit_y
                if log == True:
                    duration = time.time() - t0
                    self.log = np.append(self.log, [obj0, duration])
                break

            # adaptive line search

            # ready to update time now and check convergence
            with torch.no_grad():
                beta = 0.0001
                y = torch.from_numpy(candidit_y)
                c_pre = c_0
                c_0 -= beta * c_0.grad
            # y.grad.zero_()
            # this is the alpha we desire
            if self.verbose:
                print('obj0 = ', obj0, 'obj = ', obj)
            if log == True:
                duration = time.time() - t0
                # we log the objective and duration for each major iteration
                if self.verbose == True:
                    print("Logging: obj: %f, T: %f" % (obj, duration))
                self.log = np.append(self.log, [obj, duration])
            if abs(obj - obj0) < self.abs_obj_tol:
                if self.verbose:
                    print('Absolute obj improvement too small')
                converged = True
                converge_reason = 'Absolute cost'
                break
            elif abs(obj - obj0) / abs(obj0) < self.rel_obj_tol:
                if self.verbose:
                    print('Relative obj improvement too small')
                converged = True
                converge_reason = 'Relative cost'
                break
        self.major_iteration = i
        self.num_prob_solve = num_prob_solve
        self.time_cost = time.time() - t0
        self.converge_reason = converge_reason
        return is_okay, converged


    def Cournot(self, alpha0=0.002, h=1e-5, c=0.2, tau=0.001, max_iter=2000, j_iter=50, log=False, timeProfile=False, adaptiveLineSearch=False):
        """Use backtrack line search to refine time. We fix total time to make things easier.

        Parameters
        ----------
        alpha0: float, initial step length 0.175 and 0.375 are found to be very good.
        h: float, step size for finding gradient using forward differentiation
        c: float, the objective decrease parameter
        tau: float, the step length shrink parameter
        max_iter: int, maximum iteration for gradient descent
        j_iter: int, maximum iteration for finding alpha
        abs_tol: float, absolute objective tolerance
        rel_tol: float, Relative objective tolerance
        Returns
        -------
        is_okay: bool, indicates if some exception occurs
        converged: bool, indicates if the algorithm converges
        """

        if log == True:
            self.log = np.array([])
            self.log = np.append(self.log, [self.obj, 0])

        if timeProfile == True:
            self.timeProfile = np.array([])

        t0 = time.time()

        self.major_iteration = 0
        self.num_prob_solve = 0
        if self.num_box == 1 and self.tfweight == 0:
            self.major_iteration = 0
            self.num_prob_solve = 0
            self.time_cost = time.time() - t0
            self.converge_reason = 'No need to refine'
            return True, True
        n_room = self.num_box
        # t_now = self.room_time.copy()
        y = torch.tensor(self.room_time, dtype=torch.double) #, dtype = torch.double

        y.requires_grad_()

        converged = False
        converge_reason = 'Not converged'
        num_prob_solve = 0  # record number of problems being solved for a BTLS
        T = 10
        dim = 3*self.num_box*(self.poly_order+1)
        # c_0 = torch.zeros(dim, dtype=torch.double,requires_grad=True)
        c_0 = torch.tensor([dim*[0]], dtype=torch.double,requires_grad=True)
        self.floor.updateCorridorTime(y.detach().numpy())
        IndoorOptProblem.update_prob(self) #update y for c
        # c_0 = torch.tensor([(self.xlb+self.xub)/2], dtype=torch.double,requires_grad=True)

        
        # print("test:"+str(Hierarchy_free.l(self, p_y, y, c_0)))
        # print(p_y)
        obj = torch.zeros(1, dtype=torch.double,requires_grad=True)
        for k in range(max_iter):
            if self.verbose:
                print_green('Iteration %d' % i)
           
            obj0 = obj
            is_okay = True
            
            if timeProfile == True:
                tBeforeGrad = time.time()
            
            # y = torch.tensor([3.80504758, 1.14997985, 0.83818007],dtype=torch.double)
            y.requires_grad_()
            self.floor.updateCorridorTime(y.detach().numpy())
            IndoorOptProblem.update_prob(self) #update y for c

            c = c_0
            qval, qrow, qcol = Hierarchy_free.construct_P_matrix(self.obj_order, self.num_box, self.poly_order, y, self.MQM, self.h_type)
            # p_y = torch.sparse_coo_tensor((qrow, qcol), qval).to_sparse_csr()
            p_y = torch.sparse_coo_tensor((qrow, qcol), qval).to_dense()
            p_y = p_y + p_y.t() - torch.diag(p_y.diagonal())

            i = 0
            while i < T:
                c = Hierarchy_free.h(self, p_y, y, c)              
                i += 1
            
             
            obj = Hierarchy_free.l(self, p_y, y, c)
            # print("obj:")
            print(obj, y)
            self.sol = c.detach().numpy()
            self.room_time = y.detach().numpy()
            if(k==0):
                IndoorOptProblem.draw3D(self)
            obj.backward()  
            grad = y.grad.detach().numpy()

            candidit_y= y.detach().numpy()
            # choose a method to calculate gradient
            # if self.grad_method == 'ours':
            #     grad = y.grad
            # elif self.grad_method == 'fd':
            #     grad = self.get_gradient_fd(h=0.25*1e-6)
            # elif self.grad_method == 'mel':
            #     grad = self.get_gradient_mellinger(h=0.25*1e-6)
            # else:
            #     print_red("No this grad method!")
            
            if timeProfile == True:
                tAfterGrad = time.time()
                self.timeProfile = np.append(self.timeProfile, [tAfterGrad - tBeforeGrad])

            #print_red('grad_an ', grad, ' grad_fd ', grad_fd, 'grad_mel', grad_mel)
            if self.tfweight == 0:
                # get projected gradient, the linear manifold is \sum x_i = 0; if tfweight=0, we fix total time
                normal = np.ones(n_room) / np.sqrt(n_room) # normal direction
                grad = grad - grad.dot(normal) * normal  # projected gradient descent direction
            # print_red('grad_an ', grad / np.linalg.norm(grad), ' grad_fd ', grad_fd / np.linalg.norm(grad_fd), 'grad_mel', grad_mel / np.linalg.norm(grad_mel))
            # print_yellow('sum_an ', np.sum(grad), 'sum_fd ', np.sum(grad_fd), 'sum_mel ', np.sum(grad_mel))
            if np.linalg.norm(grad) < self.grad_tol:  # break out if gradient is too small
                if self.verbose:
                    print('Gradient too small')
                converged = True
                converge_reason = 'Small gradient'
                break
            if self.verbose:
                print_green('At time ', candidit_y, ' grad is ', grad)
            m = np.linalg.norm(grad)
            # print(m)
            p = grad / m  # p is the descending direction
            # use a maximum alpha that makes sure time are always positive
            # alpha_max = np.amax(-candidit_y / p) - 1e-6  # so I still get non-zero things
            
            alpha = alpha0
            # t = -c * m

            # find alpha
            alpha_found = False

            if timeProfile == True:
                tBeforeAlpha = time.time()

            for j in range(j_iter):
                if self.verbose:
                    print('Search alpha step %d, alpha = %f' % (j, alpha))
                #candidit_y = y.detach().numpy() - alpha/math.sqrt(k+1) * p
                candidit_y = y.detach().numpy() - alpha * grad / math.sqrt(m)
                # lower bound on the alpha
                if adaptiveLineSearch == True:
                    if alpha < 1e-4:
                        if self.verbose:
                            print_yellow('Stop line search because alpha is too small')
                        break
                
                # make sure that time will not go too small
                if np.any(candidit_y < 1e-6):
                    print("line search")
                    alpha = tau * alpha
                    continue
                alpha_found = True
                break

            if timeProfile == True:
                tAfterAlpha = time.time()
                self.timeProfile = np.append(self.timeProfile, [tAfterAlpha - tBeforeAlpha])

            if self.verbose:
                if alpha_found:
                    print('We found alpha = %f' % alpha)
                else:
                    print('Fail to find alpha, use a conservative %f' % alpha)
            if not alpha_found:  # for case where alpha is not found
                converge_reason = 'Cannot find step size alpha'
                is_okay = True
                converged = False
                # roll back to t_now
                self.room_time = candidit_y
                if log == True:
                    duration = time.time() - t0
                    self.log = np.append(self.log, [obj0, duration])
                break

            # adaptive line search

            # ready to update time now and check convergence
            with torch.no_grad():
                c_0 = Hierarchy_free.h(self, p_y, y, c)
                y = torch.from_numpy(candidit_y)
            # y.grad.zero_()
            # this is the alpha we desire
            if self.verbose:
                print('obj0 = ', obj0, 'obj = ', obj)
            if log == True:
                duration = time.time() - t0
                # we log the objective and duration for each major iteration
                if self.verbose == True:
                    print("Logging: obj: %f, T: %f" % (obj, duration))
                self.log = np.append(self.log, [obj, duration])
            if abs(obj - obj0) < self.abs_obj_tol:
                if self.verbose:
                    print('Absolute obj improvement too small')
                converged = True
                converge_reason = 'Absolute cost'
                break
            elif abs(obj - obj0) / abs(obj0) < self.rel_obj_tol:
                if self.verbose:
                    print('Relative obj improvement too small')
                converged = True
                converge_reason = 'Relative cost'
                break
            k += 1
        self.major_iteration = i
        self.num_prob_solve = num_prob_solve
        self.time_cost = time.time() - t0
        self.converge_reason = converge_reason
        return is_okay, converged

    


    
class IndoorQPProblemMOSEK(IndoorOptProblem):
    """Use mosek solver to solve this problem in cvxopt interface or not"""
    def __init__(self, tgp, tfweight=0, connect_order=2, verbose=False):
        IndoorOptProblem.__init__(self, tgp, tfweight, connect_order, verbose)
        self.h_type = "L"

    def solve_once(self):

        self.update_prob()

        # set up A
        A_sp = self.sp_A.tocsc()
        colptr, asub, acof = A_sp.indptr, A_sp.indices, A_sp.data
        aptrb, aptre = colptr[:-1], colptr[1:]
        # set up bounds on x
        bkx = self.n_var * [mosek.boundkey.ra]
        bkc = self.n_con * [mosek.boundkey.ra]
        with mosek.Env() as env:
            with env.Task(0, 1) as task:
                task.inputdata(self.n_con, self.n_var, self.qp_q.tolist(), 0.0,
                                list(aptrb), list(aptre), list(asub), list(acof),
                                bkc, self.clb.tolist(), self.cub.tolist(), 
                                bkx, self.xlb.tolist(), self.xub.tolist()
                                )
                # set up lower triangular part of P
                task.putqobj(self.sp_P.row.tolist(), self.sp_P.col.tolist(), self.sp_P.data.tolist())
                task.putobjsense(mosek.objsense.minimize)
                task.optimize()
                solsta = task.getsolsta(mosek.soltype.itr)
                x = self.n_var * [0.0]
                task.getsolutionslice(mosek.soltype.itr, mosek.solitem.xx, 0, self.n_var, x)
                x = np.array(x)
                # get dual variables on linear constraints
                zu, zl = self.n_con * [0.0], self.n_con * [0.0]
                task.getsolutionslice(mosek.soltype.itr, mosek.solitem.suc, 0, self.n_con, zu)
                task.getsolutionslice(mosek.soltype.itr, mosek.solitem.slc, 0, self.n_con, zl)
                z = np.array(zu) - np.array(zl)
                # get dual variables on variable bounds
                yu, yl = self.n_var * [0.0], self.n_var * [0.0]
                task.getsolutionslice(mosek.soltype.itr, mosek.solitem.sux, 0, self.n_var, yu)
                task.getsolutionslice(mosek.soltype.itr, mosek.solitem.slx, 0, self.n_var, yl)
                y = np.array(yu) - np.array(yl)
                if self.verbose:
                    print("Solving status", solsta)
                if solsta == mosek.solsta.optimal: #solsta == mosek.solsta.near_optimal: near_optimal is longer valid in Mosek 9.0
                    self.is_solved = True
                    self.obj = task.getprimalobj(mosek.soltype.itr) + self.tfweight * np.sum(self.room_time)
                    self.sol = x
                    self.lmdy = z
                    self.lmdz = y
                    return solsta, x, z, y
                else:
                    self.is_solved = False
                    self.obj = np.inf
                    #print("Mosek Failed, solsta: ", solsta)
                    return solsta, None, None, None
                
class Hierarchy_free(IndoorOptProblem):
    """Use mosek solver to solve this problem in cvxopt interface or not"""
    def __init__(self, tgp, tfweight=0, connect_order=2, verbose=False):
        IndoorOptProblem.__init__(self, tgp, tfweight, connect_order, verbose)
        
    def construct_P_matrix(minimize_order, segment_num, poly_order, room_time, MQM, ptype):
        min_order_l = int(np.floor(minimize_order))
        min_order_u = int(np.ceil(minimize_order))

        NUMQNZ = 0
        NUMQ_blk = poly_order + 1  # default minimize the jerk and minimize_order = 3
        if ptype.lower() == "f":
            NUMQNZ = segment_num * 3 * (NUMQ_blk ** 2)
        else:
            NUMQNZ = segment_num * 3 * NUMQ_blk * (NUMQ_blk + 1) / 2

        qval = torch.zeros(int(NUMQNZ),dtype=torch.double)
        qsubi = np.zeros(int(NUMQNZ),dtype=int)
        qsubj = np.zeros(int(NUMQNZ),dtype=int)
        
        sub_shift = 0
        idx = 0
        s1d1CtrlP_num = poly_order + 1
        s1CtrlP_num = 3 * s1d1CtrlP_num

        for k in range(segment_num):
            scale_k = room_time[k]
            for p in range(3):
                for i in range(s1d1CtrlP_num):
                    for j in range(s1d1CtrlP_num):
                        if ((ptype.lower() == "l" and i >= j) or (ptype.lower() == "u" and i <= j) or ptype.lower() == "f"):
                            qsubi[idx] = sub_shift + p * s1d1CtrlP_num + i
                            qsubj[idx] = sub_shift + p * s1d1CtrlP_num + j

                            if min_order_l == min_order_u:
                                qval[idx] = MQM[i][j] / (scale_k ** (2 * min_order_u - 3))
                            else:
                                qval[idx] = ((minimize_order - min_order_l) / (scale_k ** (2 * min_order_u - 3)) +
                                            (min_order_u - minimize_order) / (scale_k ** (2 * min_order_l - 3))) * MQM[i][j]
                            idx += 1

            sub_shift += s1CtrlP_num
        # p_coomatrix = torch.sparse_coo_tensor((qsubi, qsubj), qval)
        # return p_coomatrix.to_dense()
        return qval, qsubi, qsubj

    # def df(self, p_y, c): # derivative of lower-level cost with respect to variable c
    #     return 2 * p_y @ c
    
    # def l(self, p_y, y, c):  # loss fsunction

    #     return torch.dot(c, p_y @ c) #   + sum(torch.tensor(self.tfweight)* y)


    def df(self, p_y, y, c): # derivative of lower-level cost with respect to variable c
        # result = 2*torch.sparse.mm(p_y, c.T)
        result = 2*p_y @ c.T
        return result
    
    def l(self, p_y, y, c):  # loss function
        # return 0.5 * torch.sparse.mm(Hierarchy_free.df(self, p_y, y, c).T, c.T) #   + sum(torch.tensor(self.tfweight)* y)
        return 0.5 * c @ (p_y@c.T)
    
    def h(self, p_y, y, c):  # solving lower-level problem c

        dim = 3*self.num_box*(self.poly_order+1)
        c_var = cp.Variable(dim)
        b_par = cp.Parameter(dim)
        constraints = [self.sp_A @ c_var == self.clb, c_var<=self.xub, c_var>=self.xlb]  #
        objective = cp.Minimize(cp.pnorm(c_var - b_par, p=2))
        problem = cp.Problem(objective, constraints)
        assert problem.is_dpp()
        # v = time.time()
        f = Hierarchy_free.df(self, p_y, y, c).T
        b = c - self.r * f /(torch.sum(abs(f))+1)
        #b = c - self.r * f
        # print("norm_f:")
        # print(torch.sum(abs(f)))    #/ torch.sum(abs(f))
        # print("time df:"+str(time.time()-v))
        # v = time.time()
        cvxpylayer = CvxpyLayer(problem, parameters=[b_par], variables=[c_var])
        # print("time cvlayer:"+str(time.time()-v))
        c = cvxpylayer(b)[0]
        return c




"""Test the backtrack line search with IP solver."""
prob = 58

tgp = loadTGP('dataset/tgp_%d.tgp' % prob)  # every time you have to reload from hard disk since it is modified before
initial_time_allocation = np.array([box.t for box in tgp.getCorridor()])
    
# we do not limit velocity in the open source implementation
tgp.doLimitVelocity = False
# we minimize jerk
tgp.minimizeOrder = 3
# we use 6-th order piecewise Bezier spline
tgp.trajectoryOrder = 6
    
#print_green("Use Mosek + Adaptive line search")
    
solver = IndoorOptProblem(tgp, verbose=False)

# %%
solver.Cournot()
# Out:
# tensor([[35381.4807]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.5795, 3.1623, 1.8457, 0.8165, 2.4049, 1.7450, 0.8287, 1.5614, 0.9329,
#         1.7897, 0.8382], dtype=torch.float64, requires_grad=True)
# tensor([[11677.3893]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.5085, 3.0862, 1.7744, 1.2117, 2.3340, 1.6718, 0.7514, 1.5018, 0.8825,
#         1.7233, 1.0592], dtype=torch.float64, requires_grad=True)
# tensor([[6234.0949]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4661, 3.0425, 1.7376, 1.3279, 2.2910, 1.6303, 0.7318, 1.4763, 0.8672,
#         1.6873, 1.2468], dtype=torch.float64, requires_grad=True)
# tensor([[4436.2580]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4365, 3.0104, 1.7143, 1.4275, 2.2600, 1.6007, 0.7240, 1.4632, 0.8582,
#         1.6738, 1.3362], dtype=torch.float64, requires_grad=True)
# tensor([[3427.9850]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4121, 2.9827, 1.6958, 1.4994, 2.2335, 1.5760, 0.7193, 1.4532, 0.8519,
#         1.6773, 1.4035], dtype=torch.float64, requires_grad=True)
# tensor([[2753.6857]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3922, 2.9583, 1.6803, 1.5550, 2.2105, 1.5552, 0.7128, 1.4438, 0.8471,
#         1.6911, 1.4586], dtype=torch.float64, requires_grad=True)
# tensor([[2260.6601]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3756, 2.9363, 1.6667, 1.5989, 2.1900, 1.5369, 0.7065, 1.4359, 0.8431,
#         1.7087, 1.5062], dtype=torch.float64, requires_grad=True)
# tensor([[1897.2877]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3620, 2.9162, 1.6547, 1.6341, 2.1718, 1.5209, 0.7003, 1.4297, 0.8392,
#         1.7267, 1.5491], dtype=torch.float64, requires_grad=True)
# tensor([[1626.1331]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3508, 2.8977, 1.6440, 1.6627, 2.1554, 1.5067, 0.6942, 1.4254, 0.8359,
#         1.7438, 1.5884], dtype=torch.float64, requires_grad=True)
# tensor([[1421.7752]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3413, 2.8802, 1.6343, 1.6869, 2.1402, 1.4939, 0.6881, 1.4228, 0.8335,
#         1.7594, 1.6244], dtype=torch.float64, requires_grad=True)
# tensor([[1260.9626]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3332, 2.8634, 1.6254, 1.7069, 2.1260, 1.4818, 0.6824, 1.4218, 0.8328,
#         1.7734, 1.6578], dtype=torch.float64, requires_grad=True)
# tensor([[1134.5778]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3263, 2.8474, 1.6174, 1.7238, 2.1126, 1.4705, 0.6772, 1.4223, 0.8322,
#         1.7862, 1.6891], dtype=torch.float64, requires_grad=True)
# tensor([[1026.7987]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3202, 2.8319, 1.6100, 1.7381, 2.1000, 1.4597, 0.6725, 1.4239, 0.8323,
#         1.7978, 1.7184], dtype=torch.float64, requires_grad=True)
# tensor([[934.1779]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3148, 2.8169, 1.6031, 1.7501, 2.0882, 1.4493, 0.6685, 1.4265, 0.8331,
#         1.8081, 1.7462], dtype=torch.float64, requires_grad=True)
# tensor([[853.3689]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3101, 2.8024, 1.5968, 1.7598, 2.0773, 1.4393, 0.6651, 1.4299, 0.8349,
#         1.8169, 1.7725], dtype=torch.float64, requires_grad=True)
# tensor([[781.3105]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3058, 2.7883, 1.5908, 1.7678, 2.0670, 1.4296, 0.6625, 1.4337, 0.8373,
#         1.8245, 1.7975], dtype=torch.float64, requires_grad=True)
# tensor([[715.7445]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3021, 2.7747, 1.5853, 1.7741, 2.0575, 1.4201, 0.6609, 1.4376, 0.8401,
#         1.8309, 1.8214], dtype=torch.float64, requires_grad=True)
# tensor([[655.3166]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2989, 2.7616, 1.5802, 1.7791, 2.0487, 1.4110, 0.6606, 1.4413, 0.8429,
#         1.8363, 1.8442], dtype=torch.float64, requires_grad=True)
# tensor([[600.9648]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2962, 2.7492, 1.5755, 1.7830, 2.0407, 1.4023, 0.6606, 1.4447, 0.8457,
#         1.8408, 1.8661], dtype=torch.float64, requires_grad=True)
# tensor([[554.0100]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2940, 2.7374, 1.5713, 1.7859, 2.0334, 1.3941, 0.6604, 1.4480, 0.8483,
#         1.8448, 1.8873], dtype=torch.float64, requires_grad=True)
# tensor([[511.0907]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2923, 2.7261, 1.5675, 1.7881, 2.0267, 1.3863, 0.6605, 1.4510, 0.8505,
#         1.8480, 1.9079], dtype=torch.float64, requires_grad=True)
# tensor([[472.8476]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2909, 2.7155, 1.5641, 1.7895, 2.0207, 1.3788, 0.6607, 1.4536, 0.8523,
#         1.8508, 1.9278], dtype=torch.float64, requires_grad=True)
# tensor([[438.6799]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2900, 2.7054, 1.5609, 1.7905, 2.0152, 1.3718, 0.6611, 1.4560, 0.8538,
#         1.8530, 1.9471], dtype=torch.float64, requires_grad=True)
# tensor([[408.1847]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2893, 2.6959, 1.5580, 1.7911, 2.0102, 1.3652, 0.6617, 1.4579, 0.8550,
#         1.8548, 1.9658], dtype=torch.float64, requires_grad=True)
# tensor([[380.9841]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2889, 2.6868, 1.5552, 1.7914, 2.0057, 1.3588, 0.6621, 1.4596, 0.8559,
#         1.8562, 1.9840], dtype=torch.float64, requires_grad=True)
# tensor([[357.2160]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2888, 2.6783, 1.5526, 1.7916, 2.0016, 1.3531, 0.6625, 1.4609, 0.8565,
#         1.8573, 2.0017], dtype=torch.float64, requires_grad=True)
# tensor([[335.8737]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2889, 2.6700, 1.5500, 1.7916, 1.9980, 1.3479, 0.6627, 1.4619, 0.8567,
#         1.8580, 2.0189], dtype=torch.float64, requires_grad=True)
# tensor([[316.5048]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2892, 2.6621, 1.5474, 1.7914, 1.9947, 1.3433, 0.6630, 1.4626, 0.8568,
#         1.8584, 2.0357], dtype=torch.float64, requires_grad=True)
# tensor([[298.5458]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2897, 2.6546, 1.5449, 1.7912, 1.9919, 1.3392, 0.6633, 1.4631, 0.8566,
#         1.8585, 2.0519], dtype=torch.float64, requires_grad=True)
# tensor([[281.7349]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2903, 2.6472, 1.5423, 1.7910, 1.9894, 1.3356, 0.6636, 1.4634, 0.8562,
#         1.8584, 2.0675], dtype=torch.float64, requires_grad=True)
# tensor([[266.9137]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2910, 2.6401, 1.5398, 1.7909, 1.9873, 1.3326, 0.6634, 1.4636, 0.8557,
#         1.8580, 2.0825], dtype=torch.float64, requires_grad=True)
# tensor([[252.7809]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2918, 2.6332, 1.5374, 1.7908, 1.9855, 1.3298, 0.6636, 1.4636, 0.8548,
#         1.8572, 2.0971], dtype=torch.float64, requires_grad=True)
# tensor([[239.8344]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2928, 2.6265, 1.5349, 1.7907, 1.9841, 1.3274, 0.6638, 1.4636, 0.8537,
#         1.8562, 2.1111], dtype=torch.float64, requires_grad=True)
# tensor([[227.7735]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2938, 2.6200, 1.5325, 1.7908, 1.9829, 1.3253, 0.6640, 1.4634, 0.8525,
#         1.8549, 2.1247], dtype=torch.float64, requires_grad=True)
# tensor([[216.5491]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2949, 2.6137, 1.5302, 1.7909, 1.9821, 1.3235, 0.6643, 1.4631, 0.8511,
#         1.8533, 2.1378], dtype=torch.float64, requires_grad=True)
# tensor([[206.0733]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2961, 2.6076, 1.5280, 1.7911, 1.9815, 1.3219, 0.6645, 1.4627, 0.8496,
#         1.8515, 2.1504], dtype=torch.float64, requires_grad=True)
# tensor([[196.3246]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2974, 2.6017, 1.5259, 1.7913, 1.9813, 1.3204, 0.6648, 1.4622, 0.8479,
#         1.8495, 2.1625], dtype=torch.float64, requires_grad=True)
# tensor([[187.3192]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.2988, 2.5959, 1.5239, 1.7916, 1.9812, 1.3191, 0.6649, 1.4617, 0.8462,
#         1.8472, 2.1743], dtype=torch.float64, requires_grad=True)
# tensor([[178.9360]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3003, 2.5903, 1.5220, 1.7920, 1.9815, 1.3180, 0.6650, 1.4612, 0.8444,
#         1.8447, 2.1856], dtype=torch.float64, requires_grad=True)
# tensor([[171.1037]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3018, 2.5848, 1.5202, 1.7924, 1.9819, 1.3170, 0.6651, 1.4606, 0.8424,
#         1.8420, 2.1965], dtype=torch.float64, requires_grad=True)
# tensor([[163.8035]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3033, 2.5796, 1.5184, 1.7929, 1.9825, 1.3161, 0.6653, 1.4600, 0.8405,
#         1.8392, 2.2071], dtype=torch.float64, requires_grad=True)
# tensor([[157.0538]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3050, 2.5744, 1.5167, 1.7935, 1.9833, 1.3154, 0.6654, 1.4593, 0.8385,
#         1.8362, 2.2173], dtype=torch.float64, requires_grad=True)
# tensor([[150.7864]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3066, 2.5694, 1.5150, 1.7940, 1.9842, 1.3147, 0.6654, 1.4586, 0.8365,
#         1.8331, 2.2272], dtype=torch.float64, requires_grad=True)
# tensor([[145.3257]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3084, 2.5645, 1.5134, 1.7946, 1.9852, 1.3141, 0.6655, 1.4579, 0.8346,
#         1.8299, 2.2368], dtype=torch.float64, requires_grad=True)
# tensor([[140.4657]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3101, 2.5597, 1.5117, 1.7951, 1.9863, 1.3135, 0.6654, 1.4569, 0.8333,
#         1.8266, 2.2462], dtype=torch.float64, requires_grad=True)
# tensor([[135.7907]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3118, 2.5550, 1.5101, 1.7956, 1.9874, 1.3130, 0.6653, 1.4559, 0.8323,
#         1.8232, 2.2552], dtype=torch.float64, requires_grad=True)
# tensor([[131.3276]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3135, 2.5503, 1.5085, 1.7962, 1.9886, 1.3125, 0.6652, 1.4547, 0.8315,
#         1.8198, 2.2640], dtype=torch.float64, requires_grad=True)
# tensor([[127.1216]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3152, 2.5458, 1.5070, 1.7967, 1.9898, 1.3121, 0.6650, 1.4535, 0.8309,
#         1.8164, 2.2726], dtype=torch.float64, requires_grad=True)
# tensor([[123.2131]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3170, 2.5413, 1.5054, 1.7973, 1.9910, 1.3117, 0.6649, 1.4522, 0.8303,
#         1.8129, 2.2809], dtype=torch.float64, requires_grad=True)
# tensor([[119.6114]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3187, 2.5369, 1.5039, 1.7978, 1.9922, 1.3114, 0.6647, 1.4508, 0.8298,
#         1.8095, 2.2890], dtype=torch.float64, requires_grad=True)
# tensor([[116.3346]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3205, 2.5326, 1.5024, 1.7983, 1.9935, 1.3111, 0.6645, 1.4494, 0.8294,
#         1.8061, 2.2969], dtype=torch.float64, requires_grad=True)
# tensor([[113.3723]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3223, 2.5284, 1.5009, 1.7987, 1.9947, 1.3109, 0.6642, 1.4480, 0.8292,
#         1.8029, 2.3047], dtype=torch.float64, requires_grad=True)
# tensor([[110.6819]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3241, 2.5242, 1.4993, 1.7991, 1.9959, 1.3106, 0.6640, 1.4465, 0.8290,
#         1.7998, 2.3123], dtype=torch.float64, requires_grad=True)
# tensor([[108.2083]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3259, 2.5201, 1.4978, 1.7994, 1.9970, 1.3104, 0.6637, 1.4450, 0.8289,
#         1.7969, 2.3198], dtype=torch.float64, requires_grad=True)
# tensor([[105.9252]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3277, 2.5159, 1.4963, 1.7997, 1.9981, 1.3102, 0.6634, 1.4435, 0.8289,
#         1.7941, 2.3271], dtype=torch.float64, requires_grad=True)
# tensor([[103.8276]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3295, 2.5118, 1.4949, 1.7998, 1.9991, 1.3100, 0.6630, 1.4419, 0.8290,
#         1.7916, 2.3342], dtype=torch.float64, requires_grad=True)
# tensor([[101.8913]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3312, 2.5078, 1.4934, 1.7999, 2.0000, 1.3099, 0.6627, 1.4403, 0.8291,
#         1.7893, 2.3413], dtype=torch.float64, requires_grad=True)
# tensor([[100.0917]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3330, 2.5037, 1.4919, 1.7998, 2.0009, 1.3098, 0.6623, 1.4388, 0.8294,
#         1.7872, 2.3482], dtype=torch.float64, requires_grad=True)
# tensor([[98.4089]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3348, 2.4996, 1.4903, 1.7996, 2.0016, 1.3098, 0.6619, 1.4372, 0.8297,
#         1.7854, 2.3549], dtype=torch.float64, requires_grad=True)
# tensor([[96.8225]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3366, 2.4955, 1.4888, 1.7994, 2.0022, 1.3099, 0.6614, 1.4356, 0.8301,
#         1.7838, 2.3615], dtype=torch.float64, requires_grad=True)
# tensor([[95.3232]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3383, 2.4914, 1.4872, 1.7990, 2.0027, 1.3100, 0.6610, 1.4340, 0.8307,
#         1.7825, 2.3680], dtype=torch.float64, requires_grad=True)
# tensor([[93.8784]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3401, 2.4874, 1.4857, 1.7985, 2.0031, 1.3102, 0.6605, 1.4325, 0.8312,
#         1.7814, 2.3743], dtype=torch.float64, requires_grad=True)
# tensor([[92.5038]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3418, 2.4833, 1.4841, 1.7979, 2.0035, 1.3105, 0.6601, 1.4309, 0.8319,
#         1.7806, 2.3804], dtype=torch.float64, requires_grad=True)
# tensor([[91.1616]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3435, 2.4792, 1.4825, 1.7972, 2.0037, 1.3109, 0.6596, 1.4294, 0.8325,
#         1.7799, 2.3864], dtype=torch.float64, requires_grad=True)
# tensor([[89.8463]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3453, 2.4751, 1.4810, 1.7963, 2.0039, 1.3112, 0.6591, 1.4280, 0.8332,
#         1.7795, 2.3922], dtype=torch.float64, requires_grad=True)
# tensor([[88.5740]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3470, 2.4710, 1.4794, 1.7954, 2.0042, 1.3115, 0.6587, 1.4266, 0.8340,
#         1.7792, 2.3979], dtype=torch.float64, requires_grad=True)
# tensor([[87.3280]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3487, 2.4670, 1.4778, 1.7944, 2.0043, 1.3118, 0.6582, 1.4254, 0.8348,
#         1.7790, 2.4034], dtype=torch.float64, requires_grad=True)
# tensor([[86.0728]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3505, 2.4629, 1.4762, 1.7933, 2.0044, 1.3121, 0.6578, 1.4242, 0.8357,
#         1.7790, 2.4087], dtype=torch.float64, requires_grad=True)
# tensor([[84.8291]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3522, 2.4588, 1.4747, 1.7921, 2.0044, 1.3125, 0.6573, 1.4231, 0.8367,
#         1.7791, 2.4139], dtype=torch.float64, requires_grad=True)
# tensor([[83.5940]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3540, 2.4548, 1.4731, 1.7909, 2.0043, 1.3129, 0.6567, 1.4223, 0.8376,
#         1.7794, 2.4189], dtype=torch.float64, requires_grad=True)
# tensor([[82.3478]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3558, 2.4507, 1.4715, 1.7896, 2.0042, 1.3132, 0.6563, 1.4216, 0.8386,
#         1.7796, 2.4238], dtype=torch.float64, requires_grad=True)
# tensor([[81.1105]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3576, 2.4466, 1.4699, 1.7882, 2.0041, 1.3134, 0.6558, 1.4212, 0.8396,
#         1.7800, 2.4284], dtype=torch.float64, requires_grad=True)
# tensor([[79.8668]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3594, 2.4426, 1.4684, 1.7867, 2.0039, 1.3136, 0.6554, 1.4209, 0.8406,
#         1.7805, 2.4329], dtype=torch.float64, requires_grad=True)
# tensor([[78.6116]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3612, 2.4385, 1.4668, 1.7852, 2.0036, 1.3138, 0.6551, 1.4209, 0.8416,
#         1.7810, 2.4372], dtype=torch.float64, requires_grad=True)
# tensor([[77.3588]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3630, 2.4344, 1.4652, 1.7836, 2.0033, 1.3140, 0.6548, 1.4211, 0.8427,
#         1.7815, 2.4413], dtype=torch.float64, requires_grad=True)
# tensor([[76.0987]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3649, 2.4304, 1.4637, 1.7819, 2.0029, 1.3141, 0.6545, 1.4214, 0.8437,
#         1.7821, 2.4452], dtype=torch.float64, requires_grad=True)
# tensor([[74.8409]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3668, 2.4263, 1.4622, 1.7803, 2.0025, 1.3143, 0.6543, 1.4219, 0.8448,
#         1.7827, 2.4488], dtype=torch.float64, requires_grad=True)
# tensor([[73.5821]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3687, 2.4223, 1.4606, 1.7785, 2.0020, 1.3146, 0.6541, 1.4226, 0.8458,
#         1.7833, 2.4523], dtype=torch.float64, requires_grad=True)
# tensor([[72.3332]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3707, 2.4182, 1.4591, 1.7768, 2.0015, 1.3150, 0.6539, 1.4234, 0.8468,
#         1.7839, 2.4555], dtype=torch.float64, requires_grad=True)
# tensor([[71.0898]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3727, 2.4142, 1.4576, 1.7750, 2.0010, 1.3154, 0.6537, 1.4243, 0.8479,
#         1.7845, 2.4585], dtype=torch.float64, requires_grad=True)
# tensor([[69.8497]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3747, 2.4102, 1.4561, 1.7732, 2.0004, 1.3158, 0.6536, 1.4254, 0.8489,
#         1.7851, 2.4613], dtype=torch.float64, requires_grad=True)
# tensor([[68.6246]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3767, 2.4063, 1.4547, 1.7714, 1.9998, 1.3164, 0.6535, 1.4267, 0.8498,
#         1.7857, 2.4639], dtype=torch.float64, requires_grad=True)
# tensor([[67.4200]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3788, 2.4024, 1.4532, 1.7696, 1.9992, 1.3171, 0.6534, 1.4280, 0.8508,
#         1.7863, 2.4662], dtype=torch.float64, requires_grad=True)
# tensor([[66.2275]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3809, 2.3984, 1.4518, 1.7677, 1.9986, 1.3178, 0.6532, 1.4295, 0.8517,
#         1.7868, 2.4684], dtype=torch.float64, requires_grad=True)
# tensor([[65.0553]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3830, 2.3946, 1.4504, 1.7659, 1.9979, 1.3187, 0.6531, 1.4312, 0.8525,
#         1.7873, 2.4703], dtype=torch.float64, requires_grad=True)
# tensor([[63.9094]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3851, 2.3908, 1.4490, 1.7641, 1.9972, 1.3197, 0.6530, 1.4329, 0.8534,
#         1.7878, 2.4720], dtype=torch.float64, requires_grad=True)
# tensor([[62.8105]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3872, 2.3870, 1.4476, 1.7622, 1.9965, 1.3207, 0.6528, 1.4348, 0.8542,
#         1.7882, 2.4735], dtype=torch.float64, requires_grad=True)
# tensor([[61.7506]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3894, 2.3833, 1.4462, 1.7604, 1.9958, 1.3219, 0.6527, 1.4369, 0.8550,
#         1.7885, 2.4747], dtype=torch.float64, requires_grad=True)
# tensor([[60.7074]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3916, 2.3796, 1.4448, 1.7587, 1.9951, 1.3232, 0.6526, 1.4390, 0.8558,
#         1.7887, 2.4758], dtype=torch.float64, requires_grad=True)
# tensor([[59.7027]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3937, 2.3760, 1.4435, 1.7569, 1.9944, 1.3246, 0.6524, 1.4413, 0.8565,
#         1.7889, 2.4767], dtype=torch.float64, requires_grad=True)
# tensor([[58.7336]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3958, 2.3724, 1.4421, 1.7551, 1.9937, 1.3262, 0.6523, 1.4436, 0.8572,
#         1.7890, 2.4773], dtype=torch.float64, requires_grad=True)
# tensor([[57.8066]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.3979, 2.3689, 1.4408, 1.7534, 1.9929, 1.3280, 0.6522, 1.4461, 0.8579,
#         1.7889, 2.4778], dtype=torch.float64, requires_grad=True)
# tensor([[56.9458]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4000, 2.3655, 1.4396, 1.7516, 1.9921, 1.3299, 0.6521, 1.4487, 0.8585,
#         1.7888, 2.4781], dtype=torch.float64, requires_grad=True)
# tensor([[56.1186]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4021, 2.3621, 1.4383, 1.7499, 1.9914, 1.3319, 0.6520, 1.4514, 0.8591,
#         1.7886, 2.4782], dtype=torch.float64, requires_grad=True)
# tensor([[55.3443]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4041, 2.3588, 1.4371, 1.7482, 1.9906, 1.3342, 0.6519, 1.4541, 0.8596,
#         1.7882, 2.4781], dtype=torch.float64, requires_grad=True)
# tensor([[54.6236]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4060, 2.3556, 1.4359, 1.7464, 1.9898, 1.3366, 0.6518, 1.4569, 0.8601,
#         1.7878, 2.4778], dtype=torch.float64, requires_grad=True)
# tensor([[53.9626]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4079, 2.3524, 1.4348, 1.7447, 1.9890, 1.3392, 0.6517, 1.4598, 0.8606,
#         1.7872, 2.4775], dtype=torch.float64, requires_grad=True)
# tensor([[53.3761]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4097, 2.3493, 1.4337, 1.7430, 1.9882, 1.3420, 0.6516, 1.4628, 0.8610,
#         1.7866, 2.4769], dtype=torch.float64, requires_grad=True)
# tensor([[52.8310]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4115, 2.3463, 1.4325, 1.7413, 1.9874, 1.3450, 0.6515, 1.4658, 0.8614,
#         1.7858, 2.4763], dtype=torch.float64, requires_grad=True)
# tensor([[52.3359]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4131, 2.3433, 1.4315, 1.7396, 1.9866, 1.3482, 0.6515, 1.4689, 0.8618,
#         1.7850, 2.4755], dtype=torch.float64, requires_grad=True)
# tensor([[51.8787]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4147, 2.3403, 1.4304, 1.7379, 1.9858, 1.3514, 0.6516, 1.4720, 0.8622,
#         1.7840, 2.4745], dtype=torch.float64, requires_grad=True)
# tensor([[51.4644]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4163, 2.3374, 1.4293, 1.7362, 1.9850, 1.3548, 0.6516, 1.4752, 0.8625,
#         1.7830, 2.4735], dtype=torch.float64, requires_grad=True)
# tensor([[51.0833]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4177, 2.3346, 1.4283, 1.7345, 1.9841, 1.3584, 0.6517, 1.4785, 0.8628,
#         1.7818, 2.4724], dtype=torch.float64, requires_grad=True)
# tensor([[50.7197]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4191, 2.3318, 1.4272, 1.7328, 1.9833, 1.3620, 0.6519, 1.4819, 0.8631,
#         1.7806, 2.4712], dtype=torch.float64, requires_grad=True)
# tensor([[50.3891]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4204, 2.3290, 1.4262, 1.7312, 1.9825, 1.3657, 0.6520, 1.4853, 0.8634,
#         1.7793, 2.4698], dtype=torch.float64, requires_grad=True)
# tensor([[50.0867]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4217, 2.3262, 1.4252, 1.7295, 1.9816, 1.3695, 0.6522, 1.4887, 0.8637,
#         1.7780, 2.4684], dtype=torch.float64, requires_grad=True)
# tensor([[49.8143]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4229, 2.3235, 1.4242, 1.7278, 1.9808, 1.3734, 0.6525, 1.4923, 0.8640,
#         1.7765, 2.4670], dtype=torch.float64, requires_grad=True)
# tensor([[49.5679]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4240, 2.3208, 1.4232, 1.7261, 1.9799, 1.3774, 0.6527, 1.4959, 0.8642,
#         1.7751, 2.4654], dtype=torch.float64, requires_grad=True)
# tensor([[49.3469]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4250, 2.3181, 1.4223, 1.7245, 1.9790, 1.3815, 0.6530, 1.4995, 0.8645,
#         1.7735, 2.4639], dtype=torch.float64, requires_grad=True)
# tensor([[49.1497]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4260, 2.3155, 1.4213, 1.7228, 1.9781, 1.3857, 0.6533, 1.5032, 0.8648,
#         1.7719, 2.4622], dtype=torch.float64, requires_grad=True)
# tensor([[48.9718]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4269, 2.3129, 1.4204, 1.7211, 1.9773, 1.3899, 0.6536, 1.5069, 0.8651,
#         1.7703, 2.4605], dtype=torch.float64, requires_grad=True)
# tensor([[48.8139]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4278, 2.3103, 1.4194, 1.7194, 1.9764, 1.3942, 0.6540, 1.5107, 0.8654,
#         1.7686, 2.4588], dtype=torch.float64, requires_grad=True)
# tensor([[48.6726]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4286, 2.3077, 1.4185, 1.7177, 1.9755, 1.3986, 0.6543, 1.5145, 0.8657,
#         1.7668, 2.4570], dtype=torch.float64, requires_grad=True)
# tensor([[48.5479]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4294, 2.3051, 1.4176, 1.7160, 1.9746, 1.4030, 0.6547, 1.5183, 0.8660,
#         1.7650, 2.4552], dtype=torch.float64, requires_grad=True)
# tensor([[48.4341]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4301, 2.3025, 1.4167, 1.7143, 1.9737, 1.4074, 0.6551, 1.5222, 0.8663,
#         1.7632, 2.4533], dtype=torch.float64, requires_grad=True)
# tensor([[48.3341]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4307, 2.3000, 1.4158, 1.7126, 1.9728, 1.4120, 0.6555, 1.5261, 0.8666,
#         1.7614, 2.4514], dtype=torch.float64, requires_grad=True)
# tensor([[48.2468]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4313, 2.2974, 1.4149, 1.7109, 1.9718, 1.4165, 0.6559, 1.5301, 0.8669,
#         1.7595, 2.4495], dtype=torch.float64, requires_grad=True)
# tensor([[48.1737]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4319, 2.2949, 1.4141, 1.7091, 1.9709, 1.4211, 0.6563, 1.5341, 0.8673,
#         1.7576, 2.4476], dtype=torch.float64, requires_grad=True)
# tensor([[48.1127]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4324, 2.2924, 1.4132, 1.7073, 1.9700, 1.4258, 0.6568, 1.5381, 0.8676,
#         1.7556, 2.4456], dtype=torch.float64, requires_grad=True)
# tensor([[48.0627]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4329, 2.2899, 1.4124, 1.7055, 1.9691, 1.4305, 0.6572, 1.5421, 0.8679,
#         1.7536, 2.4436], dtype=torch.float64, requires_grad=True)
# tensor([[48.0265]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4333, 2.2874, 1.4115, 1.7037, 1.9682, 1.4352, 0.6577, 1.5462, 0.8683,
#         1.7516, 2.4416], dtype=torch.float64, requires_grad=True)
# tensor([[48.0011]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4337, 2.2849, 1.4107, 1.7019, 1.9673, 1.4400, 0.6581, 1.5503, 0.8687,
#         1.7496, 2.4396], dtype=torch.float64, requires_grad=True)
# tensor([[47.9883]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4340, 2.2824, 1.4099, 1.7000, 1.9664, 1.4449, 0.6586, 1.5544, 0.8691,
#         1.7476, 2.4376], dtype=torch.float64, requires_grad=True)
# tensor([[48.0003]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4344, 2.2799, 1.4091, 1.6981, 1.9655, 1.4497, 0.6590, 1.5585, 0.8695,
#         1.7455, 2.4356], dtype=torch.float64, requires_grad=True)
# tensor([[48.0228]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4346, 2.2774, 1.4084, 1.6962, 1.9647, 1.4546, 0.6595, 1.5626, 0.8698,
#         1.7434, 2.4336], dtype=torch.float64, requires_grad=True)
# tensor([[48.0524]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4348, 2.2749, 1.4076, 1.6943, 1.9638, 1.4596, 0.6599, 1.5668, 0.8702,
#         1.7413, 2.4315], dtype=torch.float64, requires_grad=True)
# tensor([[48.0893]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4350, 2.2724, 1.4069, 1.6923, 1.9629, 1.4645, 0.6604, 1.5710, 0.8706,
#         1.7392, 2.4295], dtype=torch.float64, requires_grad=True)
# tensor([[48.1330]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4352, 2.2699, 1.4061, 1.6904, 1.9620, 1.4696, 0.6608, 1.5752, 0.8711,
#         1.7371, 2.4275], dtype=torch.float64, requires_grad=True)
# tensor([[48.1837]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4353, 2.2674, 1.4054, 1.6885, 1.9612, 1.4746, 0.6613, 1.5793, 0.8715,
#         1.7349, 2.4254], dtype=torch.float64, requires_grad=True)
# tensor([[48.2417]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4353, 2.2650, 1.4047, 1.6865, 1.9603, 1.4797, 0.6618, 1.5836, 0.8719,
#         1.7328, 2.4234], dtype=torch.float64, requires_grad=True)
# tensor([[48.3045]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4354, 2.2625, 1.4040, 1.6845, 1.9594, 1.4848, 0.6622, 1.5878, 0.8723,
#         1.7306, 2.4213], dtype=torch.float64, requires_grad=True)
# tensor([[48.3736]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4354, 2.2600, 1.4033, 1.6825, 1.9585, 1.4899, 0.6627, 1.5920, 0.8727,
#         1.7284, 2.4193], dtype=torch.float64, requires_grad=True)
# tensor([[48.4488]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4353, 2.2575, 1.4026, 1.6806, 1.9576, 1.4951, 0.6632, 1.5963, 0.8732,
#         1.7262, 2.4173], dtype=torch.float64, requires_grad=True)
# tensor([[48.5295]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4353, 2.2550, 1.4019, 1.6786, 1.9568, 1.5003, 0.6637, 1.6005, 0.8736,
#         1.7240, 2.4153], dtype=torch.float64, requires_grad=True)
# tensor([[48.6153]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4352, 2.2525, 1.4013, 1.6766, 1.9559, 1.5055, 0.6641, 1.6048, 0.8740,
#         1.7218, 2.4132], dtype=torch.float64, requires_grad=True)
# tensor([[48.7066]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4350, 2.2500, 1.4006, 1.6746, 1.9550, 1.5107, 0.6646, 1.6090, 0.8745,
#         1.7195, 2.4112], dtype=torch.float64, requires_grad=True)
# tensor([[48.8013]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4349, 2.2475, 1.4000, 1.6726, 1.9541, 1.5160, 0.6651, 1.6133, 0.8749,
#         1.7173, 2.4092], dtype=torch.float64, requires_grad=True)
# tensor([[48.8972]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4347, 2.2450, 1.3993, 1.6705, 1.9532, 1.5212, 0.6656, 1.6176, 0.8754,
#         1.7151, 2.4073], dtype=torch.float64, requires_grad=True)
# tensor([[48.9959]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4345, 2.2425, 1.3987, 1.6685, 1.9523, 1.5265, 0.6660, 1.6218, 0.8759,
#         1.7128, 2.4053], dtype=torch.float64, requires_grad=True)
# tensor([[49.0986]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4342, 2.2400, 1.3981, 1.6665, 1.9513, 1.5319, 0.6665, 1.6261, 0.8763,
#         1.7105, 2.4033], dtype=torch.float64, requires_grad=True)
# tensor([[49.2040]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4339, 2.2375, 1.3975, 1.6645, 1.9504, 1.5372, 0.6670, 1.6304, 0.8768,
#         1.7083, 2.4014], dtype=torch.float64, requires_grad=True)
# tensor([[49.3239]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4336, 2.2350, 1.3969, 1.6625, 1.9495, 1.5426, 0.6674, 1.6347, 0.8773,
#         1.7060, 2.3994], dtype=torch.float64, requires_grad=True)
# tensor([[49.5359]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4333, 2.2324, 1.3963, 1.6604, 1.9486, 1.5479, 0.6679, 1.6390, 0.8777,
#         1.7037, 2.3975], dtype=torch.float64, requires_grad=True)
# tensor([[49.7146]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4330, 2.2299, 1.3957, 1.6584, 1.9476, 1.5533, 0.6683, 1.6433, 0.8782,
#         1.7016, 2.3955], dtype=torch.float64, requires_grad=True)
# tensor([[49.7217]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4326, 2.2273, 1.3951, 1.6564, 1.9467, 1.5587, 0.6688, 1.6475, 0.8787,
#         1.6996, 2.3934], dtype=torch.float64, requires_grad=True)
# tensor([[49.6312]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4321, 2.2248, 1.3945, 1.6543, 1.9456, 1.5641, 0.6692, 1.6519, 0.8793,
#         1.6976, 2.3914], dtype=torch.float64, requires_grad=True)
# tensor([[49.4585]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4317, 2.2222, 1.3940, 1.6523, 1.9445, 1.5692, 0.6697, 1.6563, 0.8799,
#         1.6957, 2.3894], dtype=torch.float64, requires_grad=True)
# tensor([[49.2181]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4313, 2.2196, 1.3934, 1.6502, 1.9433, 1.5741, 0.6703, 1.6607, 0.8806,
#         1.6939, 2.3873], dtype=torch.float64, requires_grad=True)
# tensor([[48.9442]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4308, 2.2170, 1.3929, 1.6482, 1.9421, 1.5788, 0.6709, 1.6653, 0.8814,
#         1.6922, 2.3853], dtype=torch.float64, requires_grad=True)
# tensor([[48.6519]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4304, 2.2143, 1.3924, 1.6462, 1.9409, 1.5833, 0.6714, 1.6698, 0.8823,
#         1.6905, 2.3832], dtype=torch.float64, requires_grad=True)
# tensor([[48.3452]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4300, 2.2117, 1.3920, 1.6442, 1.9396, 1.5876, 0.6720, 1.6744, 0.8833,
#         1.6889, 2.3812], dtype=torch.float64, requires_grad=True)
# tensor([[48.0357]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4296, 2.2091, 1.3915, 1.6422, 1.9383, 1.5917, 0.6724, 1.6790, 0.8845,
#         1.6873, 2.3792], dtype=torch.float64, requires_grad=True)
# tensor([[47.7400]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4292, 2.2065, 1.3911, 1.6401, 1.9369, 1.5957, 0.6729, 1.6837, 0.8857,
#         1.6859, 2.3772], dtype=torch.float64, requires_grad=True)
# tensor([[47.4637]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4288, 2.2038, 1.3907, 1.6381, 1.9356, 1.5996, 0.6733, 1.6883, 0.8870,
#         1.6845, 2.3752], dtype=torch.float64, requires_grad=True)
# tensor([[47.2060]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4284, 2.2012, 1.3903, 1.6361, 1.9342, 1.6033, 0.6736, 1.6929, 0.8884,
#         1.6832, 2.3732], dtype=torch.float64, requires_grad=True)
# tensor([[46.9632]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4280, 2.1986, 1.3899, 1.6341, 1.9328, 1.6069, 0.6739, 1.6975, 0.8899,
#         1.6820, 2.3713], dtype=torch.float64, requires_grad=True)
# tensor([[46.7376]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4276, 2.1959, 1.3895, 1.6321, 1.9314, 1.6105, 0.6741, 1.7020, 0.8915,
#         1.6808, 2.3694], dtype=torch.float64, requires_grad=True)
# tensor([[46.5384]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4273, 2.1933, 1.3892, 1.6300, 1.9299, 1.6139, 0.6743, 1.7065, 0.8932,
#         1.6798, 2.3674], dtype=torch.float64, requires_grad=True)
# tensor([[46.3574]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4269, 2.1907, 1.3888, 1.6280, 1.9285, 1.6173, 0.6745, 1.7110, 0.8949,
#         1.6788, 2.3655], dtype=torch.float64, requires_grad=True)
# tensor([[46.2007]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4265, 2.1881, 1.3884, 1.6260, 1.9270, 1.6205, 0.6745, 1.7154, 0.8968,
#         1.6778, 2.3637], dtype=torch.float64, requires_grad=True)
# tensor([[46.0659]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4262, 2.1854, 1.3880, 1.6239, 1.9255, 1.6238, 0.6746, 1.7198, 0.8988,
#         1.6770, 2.3618], dtype=torch.float64, requires_grad=True)
# tensor([[45.9540]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4258, 2.1828, 1.3876, 1.6219, 1.9240, 1.6269, 0.6746, 1.7242, 0.9009,
#         1.6762, 2.3600], dtype=torch.float64, requires_grad=True)
# tensor([[45.8577]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4254, 2.1802, 1.3872, 1.6198, 1.9224, 1.6301, 0.6745, 1.7285, 0.9031,
#         1.6755, 2.3581], dtype=torch.float64, requires_grad=True)
# tensor([[46.0800]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4250, 2.1776, 1.3868, 1.6178, 1.9209, 1.6331, 0.6744, 1.7328, 0.9053,
#         1.6748, 2.3563], dtype=torch.float64, requires_grad=True)
# tensor([[46.0319]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4247, 2.1750, 1.3864, 1.6157, 1.9194, 1.6363, 0.6745, 1.7374, 0.9065,
#         1.6745, 2.3545], dtype=torch.float64, requires_grad=True)
# tensor([[45.8830]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4243, 2.1724, 1.3861, 1.6137, 1.9179, 1.6393, 0.6745, 1.7423, 0.9074,
#         1.6741, 2.3528], dtype=torch.float64, requires_grad=True)
# tensor([[45.7183]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4240, 2.1699, 1.3857, 1.6117, 1.9164, 1.6423, 0.6746, 1.7474, 0.9081,
#         1.6735, 2.3511], dtype=torch.float64, requires_grad=True)
# tensor([[45.5708]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4237, 2.1674, 1.3854, 1.6098, 1.9149, 1.6453, 0.6747, 1.7524, 0.9089,
#         1.6729, 2.3494], dtype=torch.float64, requires_grad=True)
# tensor([[45.3411]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4234, 2.1649, 1.3850, 1.6078, 1.9134, 1.6482, 0.6749, 1.7577, 0.9095,
#         1.6722, 2.3478], dtype=torch.float64, requires_grad=True)
# tensor([[45.0686]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4231, 2.1624, 1.3847, 1.6059, 1.9120, 1.6511, 0.6751, 1.7629, 0.9099,
#         1.6714, 2.3462], dtype=torch.float64, requires_grad=True)
# tensor([[44.7964]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4228, 2.1600, 1.3844, 1.6040, 1.9105, 1.6540, 0.6753, 1.7683, 0.9102,
#         1.6705, 2.3447], dtype=torch.float64, requires_grad=True)
# tensor([[44.5244]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4225, 2.1577, 1.3840, 1.6021, 1.9091, 1.6569, 0.6756, 1.7737, 0.9103,
#         1.6695, 2.3432], dtype=torch.float64, requires_grad=True)
# tensor([[44.3018]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4223, 2.1553, 1.3837, 1.6003, 1.9077, 1.6597, 0.6758, 1.7792, 0.9104,
#         1.6685, 2.3418], dtype=torch.float64, requires_grad=True)
# tensor([[44.1006]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4221, 2.1530, 1.3834, 1.5985, 1.9063, 1.6626, 0.6760, 1.7847, 0.9106,
#         1.6673, 2.3404], dtype=torch.float64, requires_grad=True)
# tensor([[43.9164]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4219, 2.1507, 1.3831, 1.5967, 1.9049, 1.6654, 0.6762, 1.7902, 0.9107,
#         1.6661, 2.3390], dtype=torch.float64, requires_grad=True)
# tensor([[43.7452]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4217, 2.1485, 1.3828, 1.5949, 1.9035, 1.6682, 0.6764, 1.7957, 0.9108,
#         1.6649, 2.3376], dtype=torch.float64, requires_grad=True)
# tensor([[43.5951]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4215, 2.1462, 1.3825, 1.5931, 1.9021, 1.6710, 0.6765, 1.8012, 0.9109,
#         1.6636, 2.3363], dtype=torch.float64, requires_grad=True)
# tensor([[43.4536]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4213, 2.1440, 1.3821, 1.5913, 1.9008, 1.6737, 0.6767, 1.8067, 0.9110,
#         1.6623, 2.3349], dtype=torch.float64, requires_grad=True)
# tensor([[43.3220]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4211, 2.1417, 1.3818, 1.5896, 1.8994, 1.6765, 0.6768, 1.8123, 0.9111,
#         1.6610, 2.3336], dtype=torch.float64, requires_grad=True)
# tensor([[43.2015]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4209, 2.1395, 1.3815, 1.5878, 1.8980, 1.6792, 0.6770, 1.8178, 0.9112,
#         1.6596, 2.3323], dtype=torch.float64, requires_grad=True)
# tensor([[43.0895]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4207, 2.1373, 1.3811, 1.5861, 1.8966, 1.6819, 0.6771, 1.8234, 0.9113,
#         1.6582, 2.3310], dtype=torch.float64, requires_grad=True)
# tensor([[42.9843]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4205, 2.1352, 1.3808, 1.5844, 1.8952, 1.6847, 0.6772, 1.8289, 0.9114,
#         1.6568, 2.3298], dtype=torch.float64, requires_grad=True)
# tensor([[42.8882]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4204, 2.1330, 1.3805, 1.5826, 1.8939, 1.6874, 0.6773, 1.8345, 0.9115,
#         1.6553, 2.3285], dtype=torch.float64, requires_grad=True)
# tensor([[42.7988]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4202, 2.1308, 1.3801, 1.5809, 1.8925, 1.6901, 0.6774, 1.8401, 0.9116,
#         1.6539, 2.3273], dtype=torch.float64, requires_grad=True)
# tensor([[42.7145]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4200, 2.1287, 1.3798, 1.5792, 1.8911, 1.6928, 0.6774, 1.8457, 0.9117,
#         1.6524, 2.3260], dtype=torch.float64, requires_grad=True)
# tensor([[42.5887]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4198, 2.1266, 1.3794, 1.5775, 1.8897, 1.6955, 0.6775, 1.8512, 0.9118,
#         1.6510, 2.3248], dtype=torch.float64, requires_grad=True)
# tensor([[42.4353]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4197, 2.1244, 1.3791, 1.5758, 1.8884, 1.6982, 0.6775, 1.8568, 0.9120,
#         1.6495, 2.3236], dtype=torch.float64, requires_grad=True)
# tensor([[42.2702]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4195, 2.1223, 1.3787, 1.5741, 1.8870, 1.7009, 0.6775, 1.8623, 0.9121,
#         1.6480, 2.3223], dtype=torch.float64, requires_grad=True)
# tensor([[42.0885]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4193, 2.1202, 1.3784, 1.5724, 1.8856, 1.7036, 0.6775, 1.8677, 0.9123,
#         1.6466, 2.3211], dtype=torch.float64, requires_grad=True)
# tensor([[41.8969]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4192, 2.1181, 1.3780, 1.5708, 1.8842, 1.7063, 0.6776, 1.8731, 0.9125,
#         1.6451, 2.3199], dtype=torch.float64, requires_grad=True)
# tensor([[41.7015]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4190, 2.1160, 1.3777, 1.5691, 1.8828, 1.7091, 0.6776, 1.8785, 0.9126,
#         1.6437, 2.3187], dtype=torch.float64, requires_grad=True)
# tensor([[41.4947]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4189, 2.1140, 1.3774, 1.5674, 1.8814, 1.7119, 0.6775, 1.8837, 0.9128,
#         1.6423, 2.3176], dtype=torch.float64, requires_grad=True)
# tensor([[41.2955]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4188, 2.1119, 1.3770, 1.5657, 1.8801, 1.7147, 0.6775, 1.8889, 0.9130,
#         1.6409, 2.3164], dtype=torch.float64, requires_grad=True)
# tensor([[41.0906]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4186, 2.1098, 1.3767, 1.5641, 1.8787, 1.7175, 0.6775, 1.8940, 0.9131,
#         1.6395, 2.3152], dtype=torch.float64, requires_grad=True)
# tensor([[40.8830]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4185, 2.1078, 1.3764, 1.5624, 1.8773, 1.7204, 0.6774, 1.8991, 0.9133,
#         1.6381, 2.3141], dtype=torch.float64, requires_grad=True)
# tensor([[40.6788]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4184, 2.1057, 1.3761, 1.5607, 1.8760, 1.7232, 0.6774, 1.9041, 0.9135,
#         1.6368, 2.3129], dtype=torch.float64, requires_grad=True)
# tensor([[40.4773]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4184, 2.1037, 1.3758, 1.5591, 1.8746, 1.7261, 0.6773, 1.9089, 0.9137,
#         1.6355, 2.3118], dtype=torch.float64, requires_grad=True)
# tensor([[40.2807]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4183, 2.1016, 1.3756, 1.5574, 1.8732, 1.7290, 0.6772, 1.9138, 0.9139,
#         1.6342, 2.3107], dtype=torch.float64, requires_grad=True)
# tensor([[40.0881]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4182, 2.0996, 1.3753, 1.5558, 1.8719, 1.7319, 0.6771, 1.9185, 0.9141,
#         1.6329, 2.3096], dtype=torch.float64, requires_grad=True)
# tensor([[39.8937]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4182, 2.0976, 1.3750, 1.5541, 1.8705, 1.7349, 0.6770, 1.9232, 0.9143,
#         1.6316, 2.3085], dtype=torch.float64, requires_grad=True)
# tensor([[39.7029]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0956, 1.3748, 1.5525, 1.8691, 1.7378, 0.6768, 1.9278, 0.9145,
#         1.6303, 2.3074], dtype=torch.float64, requires_grad=True)
# tensor([[39.5187]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0936, 1.3745, 1.5509, 1.8678, 1.7408, 0.6766, 1.9323, 0.9147,
#         1.6291, 2.3064], dtype=torch.float64, requires_grad=True)
# tensor([[39.3373]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0916, 1.3743, 1.5492, 1.8664, 1.7437, 0.6765, 1.9368, 0.9149,
#         1.6279, 2.3053], dtype=torch.float64, requires_grad=True)
# tensor([[39.1608]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0897, 1.3740, 1.5476, 1.8651, 1.7467, 0.6763, 1.9413, 0.9151,
#         1.6267, 2.3043], dtype=torch.float64, requires_grad=True)
# tensor([[38.9867]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0877, 1.3738, 1.5460, 1.8637, 1.7497, 0.6761, 1.9456, 0.9154,
#         1.6255, 2.3032], dtype=torch.float64, requires_grad=True)
# tensor([[38.8185]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0858, 1.3736, 1.5444, 1.8624, 1.7527, 0.6758, 1.9499, 0.9156,
#         1.6243, 2.3022], dtype=torch.float64, requires_grad=True)
# tensor([[38.6603]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4181, 2.0838, 1.3734, 1.5428, 1.8610, 1.7557, 0.6756, 1.9542, 0.9159,
#         1.6231, 2.3012], dtype=torch.float64, requires_grad=True)
# tensor([[38.5024]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4182, 2.0819, 1.3732, 1.5412, 1.8597, 1.7587, 0.6753, 1.9584, 0.9161,
#         1.6220, 2.3002], dtype=torch.float64, requires_grad=True)
# tensor([[38.3497]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4182, 2.0800, 1.3730, 1.5396, 1.8584, 1.7617, 0.6751, 1.9625, 0.9163,
#         1.6208, 2.2992], dtype=torch.float64, requires_grad=True)
# tensor([[38.2027]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4183, 2.0781, 1.3728, 1.5380, 1.8570, 1.7647, 0.6748, 1.9667, 0.9166,
#         1.6197, 2.2983], dtype=torch.float64, requires_grad=True)
# tensor([[38.0654]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4183, 2.0762, 1.3726, 1.5364, 1.8557, 1.7677, 0.6745, 1.9707, 0.9168,
#         1.6185, 2.2973], dtype=torch.float64, requires_grad=True)
# tensor([[37.9297]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4184, 2.0744, 1.3724, 1.5348, 1.8544, 1.7707, 0.6741, 1.9748, 0.9171,
#         1.6174, 2.2963], dtype=torch.float64, requires_grad=True)
# tensor([[37.8011]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4185, 2.0725, 1.3722, 1.5332, 1.8530, 1.7738, 0.6738, 1.9787, 0.9173,
#         1.6163, 2.2954], dtype=torch.float64, requires_grad=True)
# tensor([[37.6780]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4186, 2.0707, 1.3720, 1.5316, 1.8517, 1.7768, 0.6734, 1.9827, 0.9176,
#         1.6152, 2.2945], dtype=torch.float64, requires_grad=True)
# tensor([[37.5601]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4187, 2.0689, 1.3719, 1.5301, 1.8504, 1.7798, 0.6731, 1.9866, 0.9178,
#         1.6141, 2.2936], dtype=torch.float64, requires_grad=True)
# tensor([[37.4481]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4188, 2.0671, 1.3717, 1.5285, 1.8490, 1.7829, 0.6727, 1.9905, 0.9181,
#         1.6129, 2.2927], dtype=torch.float64, requires_grad=True)
# tensor([[37.3404]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4189, 2.0653, 1.3715, 1.5269, 1.8477, 1.7859, 0.6723, 1.9944, 0.9184,
#         1.6118, 2.2918], dtype=torch.float64, requires_grad=True)
# tensor([[37.2396]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4190, 2.0635, 1.3714, 1.5254, 1.8464, 1.7890, 0.6719, 1.9982, 0.9186,
#         1.6107, 2.2909], dtype=torch.float64, requires_grad=True)
# tensor([[37.1420]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4191, 2.0617, 1.3712, 1.5238, 1.8451, 1.7920, 0.6715, 2.0020, 0.9189,
#         1.6096, 2.2900], dtype=torch.float64, requires_grad=True)
# tensor([[37.0498]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4192, 2.0600, 1.3710, 1.5223, 1.8437, 1.7950, 0.6710, 2.0058, 0.9191,
#         1.6085, 2.2891], dtype=torch.float64, requires_grad=True)
# tensor([[36.9622]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4193, 2.0583, 1.3709, 1.5207, 1.8424, 1.7981, 0.6706, 2.0095, 0.9194,
#         1.6074, 2.2883], dtype=torch.float64, requires_grad=True)
# tensor([[36.8823]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4194, 2.0566, 1.3707, 1.5192, 1.8411, 1.8011, 0.6701, 2.0132, 0.9196,
#         1.6063, 2.2874], dtype=torch.float64, requires_grad=True)
# tensor([[36.8039]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4195, 2.0548, 1.3706, 1.5176, 1.8398, 1.8042, 0.6697, 2.0170, 0.9199,
#         1.6052, 2.2865], dtype=torch.float64, requires_grad=True)
# tensor([[36.7317]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4197, 2.0532, 1.3704, 1.5161, 1.8384, 1.8072, 0.6692, 2.0206, 0.9201,
#         1.6041, 2.2857], dtype=torch.float64, requires_grad=True)
# tensor([[36.6631]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4198, 2.0515, 1.3703, 1.5145, 1.8371, 1.8103, 0.6687, 2.0243, 0.9204,
#         1.6030, 2.2849], dtype=torch.float64, requires_grad=True)
# tensor([[36.5967]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4199, 2.0498, 1.3701, 1.5130, 1.8358, 1.8134, 0.6682, 2.0280, 0.9207,
#         1.6020, 2.2840], dtype=torch.float64, requires_grad=True)
# tensor([[36.5374]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4200, 2.0482, 1.3700, 1.5115, 1.8345, 1.8164, 0.6677, 2.0316, 0.9209,
#         1.6009, 2.2832], dtype=torch.float64, requires_grad=True)
# tensor([[36.4843]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4202, 2.0465, 1.3698, 1.5100, 1.8332, 1.8195, 0.6671, 2.0352, 0.9212,
#         1.5998, 2.2824], dtype=torch.float64, requires_grad=True)
# tensor([[36.4313]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4203, 2.0449, 1.3697, 1.5084, 1.8319, 1.8226, 0.6666, 2.0388, 0.9214,
#         1.5987, 2.2816], dtype=torch.float64, requires_grad=True)
# tensor([[36.3871]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4204, 2.0433, 1.3695, 1.5069, 1.8306, 1.8256, 0.6660, 2.0424, 0.9217,
#         1.5976, 2.2808], dtype=torch.float64, requires_grad=True)
# tensor([[36.3431]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4205, 2.0417, 1.3694, 1.5054, 1.8292, 1.8287, 0.6655, 2.0460, 0.9219,
#         1.5965, 2.2800], dtype=torch.float64, requires_grad=True)
# tensor([[36.3034]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4207, 2.0401, 1.3693, 1.5039, 1.8279, 1.8318, 0.6649, 2.0495, 0.9222,
#         1.5954, 2.2792], dtype=torch.float64, requires_grad=True)
# tensor([[36.2688]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4208, 2.0386, 1.3691, 1.5024, 1.8266, 1.8349, 0.6643, 2.0531, 0.9224,
#         1.5943, 2.2784], dtype=torch.float64, requires_grad=True)
# tensor([[36.2366]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4209, 2.0370, 1.3690, 1.5009, 1.8253, 1.8379, 0.6638, 2.0566, 0.9227,
#         1.5932, 2.2776], dtype=torch.float64, requires_grad=True)
# tensor([[36.2079]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4210, 2.0355, 1.3688, 1.4993, 1.8240, 1.8410, 0.6632, 2.0601, 0.9229,
#         1.5921, 2.2768], dtype=torch.float64, requires_grad=True)
# tensor([[36.1824]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4211, 2.0340, 1.3687, 1.4978, 1.8227, 1.8441, 0.6626, 2.0636, 0.9232,
#         1.5910, 2.2760], dtype=torch.float64, requires_grad=True)
# tensor([[36.1565]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4212, 2.0325, 1.3686, 1.4963, 1.8214, 1.8472, 0.6619, 2.0672, 0.9235,
#         1.5899, 2.2752], dtype=torch.float64, requires_grad=True)
# tensor([[36.1397]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4213, 2.0309, 1.3684, 1.4948, 1.8200, 1.8503, 0.6613, 2.0706, 0.9237,
#         1.5888, 2.2744], dtype=torch.float64, requires_grad=True)
# tensor([[36.1246]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4214, 2.0294, 1.3683, 1.4933, 1.8187, 1.8534, 0.6607, 2.0741, 0.9240,
#         1.5878, 2.2736], dtype=torch.float64, requires_grad=True)
# tensor([[36.1085]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4215, 2.0280, 1.3682, 1.4918, 1.8174, 1.8565, 0.6601, 2.0776, 0.9242,
#         1.5867, 2.2728], dtype=torch.float64, requires_grad=True)
# tensor([[36.0993]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4216, 2.0265, 1.3681, 1.4903, 1.8161, 1.8597, 0.6594, 2.0811, 0.9245,
#         1.5856, 2.2720], dtype=torch.float64, requires_grad=True)
# tensor([[36.0891]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4217, 2.0250, 1.3679, 1.4889, 1.8148, 1.8628, 0.6588, 2.0846, 0.9247,
#         1.5845, 2.2712], dtype=torch.float64, requires_grad=True)
# tensor([[36.0814]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4218, 2.0236, 1.3678, 1.4874, 1.8135, 1.8659, 0.6581, 2.0880, 0.9250,
#         1.5834, 2.2704], dtype=torch.float64, requires_grad=True)
# tensor([[36.0809]], dtype=torch.float64, grad_fn=<MmBackward0>) tensor([2.4219, 2.0221, 1.3677, 1.4859, 1.8121, 1.8691, 0.6574, 2.0915, 0.9252,
#         1.5823, 2.2697], dtype=torch.float64, requires_grad=True)
# (True, True)

# %%
solver.draw3D()
